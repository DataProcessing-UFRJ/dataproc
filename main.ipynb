# %%
from packages.data_reduce import data_reduce

# folder = './data/2021-07-10/' # SAMI data
# folder = './data/2012-10-18/' # SOI data
# folder = './data/2021-10-15/' # Goodman data
# folder = './data/2021-10-29/' # Goodman data
folder = './data/2024-12-04/' # SAMI data
# folder = './data/2015-02-12' # SAMI

summary_keywords=['obstype','object','airmass','rotoffs','dmloop','exptime']
# summary_keywords=['obstype','object','airmass','posangle','exptime']


data_reduce(folder, instrument='SAMI', 
            summary_keywords=summary_keywords, 
            multiprocessing=False)
# Out:
# .Processing 0132_SO2021B-018_1029.fits [0]o---
# .Processing 0134_SO2021B-018_1029.fits [0]o---
# .Processing 0135_SO2021B-018_1029.fits [0]o---
# .Processing 0136_SO2021B-018_1029.fits [0]o---
# .Processing 0137_SO2021B-018_1029.fits [0]o---
# .Processing 0138_SO2021B-018_1029.fits [0]o---
# .Processing 0139_SO2021B-018_1029.fits [0]o---
# .Processing 0140_SO2021B-018_1029.fits [0]o---
# .Processing 0141_SO2021B-018_1029.fits [0]o---
# .Processing 0142_SO2021B-018_1029.fits [0]o---
# .Processing 0143_SO2021B-018_1029.fits [0]o---
# .Processing 0144_SO2021B-018_1029.fits [0]o---
# .Processing 0145_SO2021B-018_1029.fits [0]o---
# .Processing 0146_SO2021B-018_1029.fits [0]o---
# .Processing 0147_SO2021B-018_1029.fits [0]o---
# .Processing 0148_SO2021B-018_1029.fits [0]o---
# .Processing 0149_SO2021B-018_1029.fits [0]o---
# .Processing 0150_SO2021B-018_1029.fits [0]o---
# .Processing 0151_SO2021B-018_1029.fits [0]o---
# .Processing 0152_SO2021B-018_1029.fits [0]o---
# .Processing 0153_SO2021B-018_1029.fits [0]o---
# .Processing 0154_SO2021B-018_1029.fits [0]o---
# .Processing 0155_SO2021B-018_1029.fits [0]o---
# .Processing 0156_SO2021B-018_1029.fits [0]o---
# .Processing 0157_SO2021B-018_1029.fits [0]o---
# .Processing 0158_SO2021B-018_1029.fits [0]o---
# .Processing 0159_SO2021B-018_1029.fits [0]o---
# .Processing 0160_SO2021B-018_1029.fits [0]o---
# .Processing 0161_SO2021B-018_1029.fits [0]o---
# .Processing 0162_SO2021B-018_1029.fits [0]o---
# .Processing 0163_SO2021B-018_1029.fits [0]o---
# .Creating 'master_bias.fits': 31 images
# .Processing 0075_SO2021B-018_1029.fits [0]oz--
# .Processing 0076_SO2021B-018_1029.fits [0]oz--
# .Processing 0077_SO2021B-018_1029.fits [0]oz--
# .Processing 0078_SO2021B-018_1029.fits [0]oz--
# .Processing 0079_SO2021B-018_1029.fits [0]oz--
# .Processing 0080_SO2021B-018_1029.fits [0]oz--
# .Processing 0081_SO2021B-018_1029.fits [0]oz--
# .Processing 0082_SO2021B-018_1029.fits [0]oz--
# .Processing 0083_SO2021B-018_1029.fits [0]oz--
# .Processing 0084_SO2021B-018_1029.fits [0]oz--
# .Processing 0086_SO2021B-018_1029.fits [0]oz--
# .Processing 0087_SO2021B-018_1029.fits [0]oz--
# .Processing 0088_SO2021B-018_1029.fits [0]oz--
# .Processing 0089_SO2021B-018_1029.fits [0]oz--
# .Processing 0090_SO2021B-018_1029.fits [0]oz--
# .Processing 0091_SO2021B-018_1029.fits [0]oz--
# .Processing 0092_SO2021B-018_1029.fits [0]oz--
# .Processing 0093_SO2021B-018_1029.fits [0]oz--
# .Processing 0094_SO2021B-018_1029.fits [0]oz--
# .Processing 0095_SO2021B-018_1029.fits [0]oz--
# .Processing 0100_SO2021B-018_1029.fits [0]oz--
# .Processing 0101_SO2021B-018_1029.fits [0]oz--
# .Processing 0102_SO2021B-018_1029.fits [0]oz--
# .Processing 0103_SO2021B-018_1029.fits [0]oz--
# .Processing 0104_SO2021B-018_1029.fits [0]oz--
# .Processing 0105_SO2021B-018_1029.fits [0]oz--
# .Processing 0106_SO2021B-018_1029.fits [0]oz--
# .Processing 0107_SO2021B-018_1029.fits [0]oz--
# .Processing 0108_SO2021B-018_1029.fits [0]oz--
# .Processing 0109_SO2021B-018_1029.fits [0]oz--
# .Processing 0111_SO2021B-018_1029.fits [0]oz--
# .Processing 0112_SO2021B-018_1029.fits [0]oz--
# .Processing 0113_SO2021B-018_1029.fits [0]oz--
# .Processing 0114_SO2021B-018_1029.fits [0]oz--
# .Processing 0115_SO2021B-018_1029.fits [0]oz--
# .Processing 0116_SO2021B-018_1029.fits [0]oz--
# .Processing 0117_SO2021B-018_1029.fits [0]oz--
# .Processing 0118_SO2021B-018_1029.fits [0]oz--
# .Processing 0119_SO2021B-018_1029.fits [0]oz--
# .Processing 0120_SO2021B-018_1029.fits [0]oz--
# .Processing 0122_SO2021B-018_1029.fits [0]oz--
# .Processing 0123_SO2021B-018_1029.fits [0]oz--
# .Processing 0124_SO2021B-018_1029.fits [0]oz--
# .Processing 0125_SO2021B-018_1029.fits [0]oz--
# .Processing 0126_SO2021B-018_1029.fits [0]oz--
# .Processing 0127_SO2021B-018_1029.fits [0]oz--
# .Processing 0128_SO2021B-018_1029.fits [0]oz--
# .Processing 0129_SO2021B-018_1029.fits [0]oz--
# .Processing 0130_SO2021B-018_1029.fits [0]oz--
# .Processing 0131_SO2021B-018_1029.fits [0]oz--
# Creating 'master_flat1.fits': 10 images (B-Bessel)
# Creating 'master_flat2.fits': 10 images (H-alpha)
# Creating 'master_flat3.fits': 10 images (I-Bessel)
# Creating 'master_flat4.fits': 10 images (Rc)
# Creating 'master_flat5.fits': 10 images (V-Bessel)
# .Processing 0173_SO2021B-018_1029.fits [0]ozf-
# .Processing 0174_SO2021B-018_1029.fits [0]ozf-
# .Processing 0175_SO2021B-018_1029.fits [0]ozf-
# .Processing 0176_SO2021B-018_1029.fits [0]ozf-
# .Processing 0177_SO2021B-018_1029.fits [0]ozf-
# .Processing 0178_SO2021B-018_1029.fits [0]ozf-
# .Processing 0179_SO2021B-018_1029.fits [0]ozf-
# .Processing 0180_SO2021B-018_1029.fits [0]ozf-
# .Processing 0181_SO2021B-018_1029.fits [0]ozf-
# .Processing 0183_SO2021B-018_1029.fits [0]ozf-
# .Processing 0184_SO2021B-018_1029.fits [0]ozf-
# .Processing 0185_SO2021B-018_1029.fits [0]ozf-
# .Processing 0186_SO2021B-018_1029.fits [0]ozf-
# .Processing 0187_SO2021B-018_1029.fits [0]ozf-
# .Processing 0188_SO2021B-018_1029.fits [0]ozf-
# .Processing 0189_SO2021B-018_1029.fits [0]ozf-
# .Processing 0190_SO2021B-018_1029.fits [0]ozf-
# .Processing 0191_SO2021B-018_1029.fits [0]ozf-
# .Processing 0192_SO2021B-018_1029.fits [0]ozf-
# .Processing 0193_SO2021B-018_1029.fits [0]ozf-
# .Processing 0194_SO2021B-018_1029.fits [0]ozf-
# .Processing 0195_SO2021B-018_1029.fits [0]ozf-
# .Processing 0196_SO2021B-018_1029.fits [0]ozf-
# .Processing 0197_SO2021B-018_1029.fits [0]ozf-
# .Processing 0198_SO2021B-018_1029.fits [0]ozf-
# .Processing 0199_SO2021B-018_1029.fits [0]ozf-
# .Processing 0200_SO2021B-018_1029.fits [0]ozf-
# .Processing 0201_SO2021B-018_1029.fits [0]ozf-
# .Processing 0202_SO2021B-018_1029.fits [0]ozf-
# .Processing 0203_SO2021B-018_1029.fits [0]ozf-
# .Processing 0204_SO2021B-018_1029.fits [0]ozf-
# .Processing 0205_SO2021B-018_1029.fits [0]ozf-
# .Processing 0206_SO2021B-018_1029.fits [0]ozf-
# .Processing 0207_SO2021B-018_1029.fits [0]ozf-
# .Processing 0208_SO2021B-018_1029.fits [0]ozf-
# .Processing 0209_SO2021B-018_1029.fits [0]ozf-
# .Processing 0210_SO2021B-018_1029.fits [0]ozf-
# .Processing 0211_SO2021B-018_1029.fits [0]ozf-
# .Processing 0212_SO2021B-018_1029.fits [0]ozf-
# .Processing 0213_SO2021B-018_1029.fits [0]ozf-
# .Processing 0214_SO2021B-018_1029.fits [0]ozf-
# .Processing 0215_SO2021B-018_1029.fits [0]ozf-
# .Processing 0216_SO2021B-018_1029.fits [0]ozf-
# .Processing 0217_SO2021B-018_1029.fits [0]ozf-
# .Processing 0218_SO2021B-018_1029.fits [0]ozf-
# .Processing 0219_SO2021B-018_1029.fits [0]ozf-
# .Processing 0220_SO2021B-018_1029.fits [0]ozf-
# .Processing 0221_SO2021B-018_1029.fits [0]ozf-
# .Processing 0222_SO2021B-018_1029.fits [0]ozf-
# .Processing 0223_SO2021B-018_1029.fits [0]ozf-
# .Processing 0224_SO2021B-018_1029.fits [0]ozf-
# .Processing 0225_SO2021B-018_1029.fits [0]ozf-
# .Processing 0226_SO2021B-018_1029.fits [0]ozf-
# .Processing 0228_SO2021B-018_1029.fits [0]ozf-
# .Processing 0229_SO2021B-018_1029.fits [0]ozf-
# .Processing 0230_SO2021B-018_1029.fits [0]ozf-
# .Processing 0231_SO2021B-018_1029.fits [0]ozf-
# .Processing 0232_SO2021B-018_1029.fits [0]ozf-
# .Processing 0233_SO2021B-018_1029.fits [0]ozf-
# .Processing 0234_SO2021B-018_1029.fits [0]ozf-
# .Processing 0235_SO2021B-018_1029.fits [0]ozf-
# .Processing 0237_SO2021B-018_1029.fits [0]ozf-
# .Processing 0238_SO2021B-018_1029.fits [0]ozf-
# .Processing 0239_SO2021B-018_1029.fits [0]ozf-
# .Processing 0240_SO2021B-018_1029.fits [0]ozf-
# .Processing 0241_SO2021B-018_1029.fits [0]ozf-
# .Processing 0242_SO2021B-018_1029.fits [0]ozf-
# .Processing 0243_SO2021B-018_1029.fits [0]ozf-
# .Processing 0244_SO2021B-018_1029.fits [0]ozf-
# .Processing 0245_SO2021B-018_1029.fits [0]ozf-
# .Processing 0246_SO2021B-018_1029.fits [0]ozf-
# .Processing 0247_SO2021B-018_1029.fits [0]ozf-
# .Processing 0248_SO2021B-018_1029.fits [0]ozf-
# .Processing 0249_SO2021B-018_1029.fits [0]ozf-
# .Processing 0250_SO2021B-018_1029.fits [0]ozf-
# .Processing 0251_SO2021B-018_1029.fits [0]ozf-
# .Processing 0252_SO2021B-018_1029.fits [0]ozf-
# .Processing 0253_SO2021B-018_1029.fits [0]ozf-
# .Processing 0254_SO2021B-018_1029.fits [0]ozf-
# .Processing 0255_SO2021B-018_1029.fits [0]ozf-
# .Processing 0256_SO2021B-018_1029.fits [0]ozf-
# .Processing 0257_SO2021B-018_1029.fits [0]ozf-
# .Processing 0258_SO2021B-018_1029.fits [0]ozf-
# .Processing 0259_SO2021B-018_1029.fits [0]ozf-
# .Processing 0260_SO2021B-018_1029.fits [0]ozf-
# .Processing 0262_SO2021B-018_1029.fits [0]ozf-
# .Processing 0263_SO2021B-018_1029.fits [0]ozf-
# .Processing 0264_SO2021B-018_1029.fits [0]ozf-
# .Processing 0265_SO2021B-018_1029.fits [0]ozf-
# .Processing 0266_SO2021B-018_1029.fits [0]ozf-
# .Processing 0267_SO2021B-018_1029.fits [0]ozf-
# .Processing 0268_SO2021B-018_1029.fits [0]ozf-
# .Processing 0269_SO2021B-018_1029.fits [0]ozf-
# .Processing 0271_SO2021B-018_1029.fits [0]ozf-
# .Processing 0272_SO2021B-018_1029.fits [0]ozf-
# .Processing 0273_SO2021B-018_1029.fits [0]ozf-
# .Processing 0274_SO2021B-018_1029.fits [0]ozf-
# .Processing 0275_SO2021B-018_1029.fits [0]ozf-
# .Processing 0276_SO2021B-018_1029.fits [0]ozf-
# .Processing 0277_SO2021B-018_1029.fits [0]ozf-
# .Processing 0278_SO2021B-018_1029.fits [0]ozf-
# .Processing 0279_SO2021B-018_1029.fits [0]ozf-
# .Processing 0280_SO2021B-018_1029.fits [0]ozf-
# .Processing 0281_SO2021B-018_1029.fits [0]ozf-
# .Processing 0282_SO2021B-018_1029.fits [0]ozf-
# .Processing 0283_SO2021B-018_1029.fits [0]ozf-
# .Processing 0284_SO2021B-018_1029.fits [0]ozf-
# .Processing 0285_SO2021B-018_1029.fits [0]ozf-
# .Processing 0286_SO2021B-018_1029.fits [0]ozf-
# .Processing 0287_SO2021B-018_1029.fits [0]ozf-
# .Processing 0288_SO2021B-018_1029.fits [0]ozf-
# .Processing 0289_SO2021B-018_1029.fits [0]ozf-
# .Processing 0290_SO2021B-018_1029.fits [0]ozf-
# .Processing 0291_SO2021B-018_1029.fits [0]ozf-
# .Processing 0292_SO2021B-018_1029.fits [0]ozf-
# .Processing 0293_SO2021B-018_1029.fits [0]ozf-
# .Processing 0295_SO2021B-018_1029.fits [0]ozf-
# .Processing 0296_SO2021B-018_1029.fits [0]ozf-
# .Processing 0297_SO2021B-018_1029.fits [0]ozf-
# .Processing 0298_SO2021B-018_1029.fits [0]ozf-
# .Processing 0299_SO2021B-018_1029.fits [0]ozf-
# .Processing 0300_SO2021B-018_1029.fits [0]ozf-
# .Processing 0301_SO2021B-018_1029.fits [0]ozf-
# .Processing 0302_SO2021B-018_1029.fits [0]ozf-
# .Processing 0304_SO2021B-018_1029.fits [0]ozf-
# .Processing 0305_SO2021B-018_1029.fits [0]ozf-
# .Processing 0306_SO2021B-018_1029.fits [0]ozf-
# .Processing 0307_SO2021B-018_1029.fits [0]ozf-
# .Processing 0308_SO2021B-018_1029.fits [0]ozf-
# .Processing 0309_SO2021B-018_1029.fits [0]ozf-
# .Processing 0310_SO2021B-018_1029.fits [0]ozf-
# .Processing 0311_SO2021B-018_1029.fits [0]ozf-
# .Processing 0312_SO2021B-018_1029.fits [0]ozf-
# .Processing 0313_SO2021B-018_1029.fits [0]ozf-
# .Processing 0314_SO2021B-018_1029.fits [0]ozf-
# .Processing 0315_SO2021B-018_1029.fits [0]ozf-
# .Processing 0316_SO2021B-018_1029.fits [0]ozf-
# .Processing 0317_SO2021B-018_1029.fits [0]ozf-
# .Processing 0318_SO2021B-018_1029.fits [0]ozf-
# .Processing 0319_SO2021B-018_1029.fits [0]ozf-
# .Processing 0320_SO2021B-018_1029.fits [0]ozf-
# .Moffat fitting ./data/2021-10-29/0173_SO2021B-018_1029.fits: median value FWHM = 5.858957234624431 (21 stars)
# .Moffat fitting ./data/2021-10-29/0174_SO2021B-018_1029.fits: median value FWHM = 6.229416946056643 (22 stars)
# .Moffat fitting ./data/2021-10-29/0175_SO2021B-018_1029.fits: median value FWHM = 6.1132666102831665 (9 stars)
# .Moffat fitting ./data/2021-10-29/0176_SO2021B-018_1029.fits: median value FWHM = 8.795686616733775 (6 stars)
# .Moffat fitting ./data/2021-10-29/0177_SO2021B-018_1029.fits: median value FWHM = 7.9129263934025555 (5 stars)
# .Moffat fitting ./data/2021-10-29/0178_SO2021B-018_1029.fits: median value FWHM = 8.161947095803674 (6 stars)
# .Moffat fitting ./data/2021-10-29/0179_SO2021B-018_1029.fits: median value FWHM = 8.50828727598002 (12 stars)
# .Moffat fitting ./data/2021-10-29/0180_SO2021B-018_1029.fits: median value FWHM = 8.8362137412897 (14 stars)
# .Moffat fitting ./data/2021-10-29/0181_SO2021B-018_1029.fits: median value FWHM = 8.152662213859394 (49 stars)

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 14
#      10 # summary_keywords=['obstype','object','airmass','rotoffs','dmloop','exptime']
#      11 summary_keywords=['obstype','object','airmass','posangle','exptime']
#      12
#      13
# ---> 14 data_reduce(folder, instrument='Goodman',
#      15             summary_keywords=summary_keywords,
#      16             multiprocessing=False)
#
# File /wbench/projects/active/dataproc/packages/data_reduce.py:115, in data_reduce(folder, filter_keywords, summary_keywords, summary_file, logfile, instrument, multiprocessing)
#     112 reject_cosmicrays(ifc)
#     114 #.solving astrometry
# --> 115 astrometry_solve(ifc, catalog='I/350', cat_magnitude='Gmag',
#     116                  multiprocessing=multiprocessing)
#     118 #.updating summary table
#     119 if summary_file:
#
# File /wbench/projects/active/dataproc/packages/astrometry_solve.py:28, in astrometry_solve(dataset, multiprocessing, **kwargs)
#      26 else:
#      27     for file in file_list:
# ---> 28         wcs_solve(file, **kwargs)
#
# File /wbench/projects/active/dataproc/packages/wcs_functions.py:159, in wcs_solve(image, catalog, cat_magnitude, cat_constraints, cat_max_objects, fit_scale_plate, match_radius, max_shift, SIP_header_file, figure)
#     147 data_pix, cat_pix = cat_match_density(data_pix, cat_pix)
#     149 # #..cutting the faintest objects to enforce the number limit
#     150 # nlim = int(cat_max_objects*np.prod(FoV+1)/np.prod(FoV))
#     151 # if ncat > nlim:
#    (...)    157
#     158 #.finding the initial translation between the catalog and image stars
# --> 159 xoff, yoff = cat_translation(data_pix, cat_pix,
#     160                              match_radius=match_radius,
#     161                              max_shift=max_shift,
#     162                              instrument=instrument, figure=figure)
#     163 hdr1 = wcs_update(hdr1, translation=np.array([xoff,yoff]))
#     164 with warnings.catch_warnings():
#
# File /wbench/projects/active/dataproc/packages/wcs_functions.py:255, in cat_translation(dat, cat, match_radius, max_shift, instrument, figure)
#     252     usedist=[False, False]
#     254 #.finding rough offset solution
# --> 255 xoffset, yoffset = cat_grid_offset(dat[:,0:2], cat[:,0:2],
#     256                                 match_radius,
#     257                                 grid_size=max_shift,
#     258                                 norm_box=6,
#     259                                 use_distance=usedist[0],
#     260                                 figure=figure)
#     261 #.refining offset solution
#     262 xoffset, yoffset = cat_grid_offset(dat[:,0:2], cat[:,0:2],
#     263                                 match_radius,
#     264                                 grid_center=(xoffset,yoffset),
#    (...)    268                                 use_distance=usedist[1],
#     269                                 figure=figure)
#
# File /wbench/projects/active/dataproc/packages/wcs_functions.py:305, in cat_grid_offset(dat, cat, match_radius, grid_center, grid_size, grid_spacing, norm_box, smooth_sigma, use_distance, figure)
#     303 for j in range(len(tgrid_y)):
#     304     xoff, yoff = tgrid_x[i], tgrid_y[j]
# --> 305     dist, _ = nbrs.kneighbors(dat+[xoff, yoff])
#     306     matches = dist <= match_radius
#     307     nmatches[j,i] = np.count_nonzero(matches)
#
# File ~/.miniforge3/envs/dataproc-env12b/lib/python3.12/site-packages/sklearn/neighbors/_base.py:916, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     911     if issparse(X):
#     912         raise ValueError(
#     913             "%s does not work with sparse matrices. Densify the data, "
#     914             "or set algorithm='brute'" % self._fit_method
#     915         )
# --> 916     chunked_results = Parallel(n_jobs, prefer="threads")(
#     917         delayed(self._tree.query)(X[s], n_neighbors, return_distance)
#     918         for s in gen_even_slices(X.shape[0], n_jobs)
#     919     )
#     920 else:
#     921     raise ValueError("internal: _fit_method not recognized")
#
# File ~/.miniforge3/envs/dataproc-env12b/lib/python3.12/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/.miniforge3/envs/dataproc-env12b/lib/python3.12/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/.miniforge3/envs/dataproc-env12b/lib/python3.12/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/.miniforge3/envs/dataproc-env12b/lib/python3.12/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
from packages.wcs_functions import wcs_solve
wcs_solve('./data/2024-12-04/SO2024B-101_0412.168.fits', 
          max_shift=500, match_radius=30, figure=True,
          cat_constraints={'Gmag': '< 20','IPDfow': '< 1','sepsi': '< 2'})
# Out:
# .WCS solving ./data/2024-12-04/SO2024B-101_0412.168.fits: MAE [1.21677806 1.26352759] pixels (77 stars)

# %%
from astropy.io import fits
# imglst = ['SO2017B-014_1220.115.fits','SO2017B-014_1220.116.fits','SO2017B-014_1220.117.fits','SO2017B-014_1220.118.fits','SO2017B-014_1220.119.fits','SO2017B-014_1220.120.fits','SO2017B-014_1220.121.fits']
# for img in imglst:
#     with fits.open('./20171220/'+img, 'update') as hdul:
#         for i in range(5): hdul[i].header['ROTOFFS'] = 34.5

imglst = ['SO2024B-101_0412.156.fits', 'SO2024B-101_0412.157.fits']
for img in imglst:
    with fits.open('./2024-12-04/raw/'+img, 'update') as hdul:
        for i in range(5): hdul[i].header['OBJECT'] = 'NGC 121'

# %%
from convenience_functions5 import soardisplay
soardisplay('./20211015/0339_SO2021B-203_1510.fits') # Goodman test - 2 sec
soardisplay('./20211015/0347_SO2021B-203_1510.fits') # Goodman test - 200 sec

# %%
from convenience_functions5 import soardisplay
soardisplay('./20210710/SO2021A-002.412.fits') # SAMI test - 10 sec
soardisplay('./20210710/SO2021A-002.420.fits') # SAMI test - 400 sec

# %%
from convenience_functions5 import soardisplay
soardisplay('./20121018/SO2012B-006_1018.566.fits') # SOI test - 5 sec
soardisplay('./20121018/SO2012B-006_1018.567.fits') # SOI test - 175 sec
